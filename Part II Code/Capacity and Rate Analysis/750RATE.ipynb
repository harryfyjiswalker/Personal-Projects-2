# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Import the Excel file
excel_file = '/Users/harryfyjis-walker/Desktop/Part II Stuff/Electrochem Data for analaysis/RATE/Manipulated rate data.xlsx'

# Step 2: Read all columns
df = pd.read_excel(excel_file)

# Step 4: Plot the data
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.plot(df['Cycle Number'], df[102750], label='0102750', marker='o', markersize=5, linewidth=2, color="forestgreen")
plt.plot(df['Cycle Number'], df[192750], label='192750', marker='o', markersize=5, linewidth=2, color="darkseagreen")
plt.plot(df['Cycle Number'], df[282750], label='282750', marker='o', markersize=5, linewidth=2, color="mediumturquoise")
plt.plot(df['Cycle Number'], df[372750], label='372750', marker='o', markersize=5, linewidth=2, color="skyblue")
plt.plot(df['Cycle Number'], df[462750], label='462750', marker='o', markersize=5, linewidth=2, color="dodgerblue")
plt.plot(df['Cycle Number'], df[552750], label='552750', marker='o', markersize=5, linewidth=2, color="darkblue")
plt.plot(df['Cycle Number'], df[642750], label='642750', marker='o', markersize=5, linewidth=2, color="purple")
plt.plot(df['Cycle Number'], df[732750], label='732750', marker='o', markersize=5, linewidth=2, color="violet")
plt.plot(df['Cycle Number'], df[822750], label='822750', marker='o', markersize=5, linewidth=2, color="hotpink")
plt.plot(df['Cycle Number'], df[912750], label='912750', marker='o', markersize=5, linewidth=2, color="crimson")
plt.plot(df['Cycle Number'], df[1002750], label='1002750', marker='o', markersize=5, linewidth=2, color="darkred")

plt.xticks(fontsize=12)  # Adjust the fontsize of xticks
plt.yticks(fontsize=12)

plt.xlabel('Cycle Number', fontsize=14)
plt.ylabel('Capacity/ mAh/g', fontsize=14)
plt.legend(fontsize=14, bbox_to_anchor=(1.24,0.82))  # Show legend
plt.ylim(-5,100)

plt.grid(True)  # Add gridlines if needed
plt.tight_layout()

plt.text(-0.5, 90,'  C/5', fontsize=14, fontweight='bold')
plt.text(5, 83,'  C/2', fontsize=14, fontweight='bold')
plt.text(11, 75,'  C', fontsize=14, fontweight='bold')
plt.text(15.5, 67,'  2C', fontsize=14, fontweight='bold')
plt.text(20, 57,'  5C', fontsize=14, fontweight='bold')


output_file = "/Users/harryfyjis-walker/Desktop/Part II Stuff/figures/PROPER750RATE.png"
plt.savefig(output_file, format='png')



plt.show()
