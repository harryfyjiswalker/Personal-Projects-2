# %%
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Import the Excel file
excel_file = '/Users/harryfyjis-walker/Desktop/Part II Stuff/Electrochem Data for analaysis/RATE/Manipulated rate data.xlsx'

# Step 2: Read all columns
df = pd.read_excel(excel_file)

# Step 4: Plot the data
plt.figure(figsize=(10, 6))  # Adjust the figure size as needed
plt.plot(df['Cycle Number'], df[282750], label='282750', marker='o', markersize=5, linewidth=2, color="lawngreen")
plt.plot(df['Cycle Number'], df[282800], label='282800', marker='o', markersize=5, linewidth=2, color="darkseagreen")
plt.plot(df['Cycle Number'], df[282850], label='282850', marker='o', markersize=5, linewidth=2, color="darkgreen")
plt.plot(df['Cycle Number'], df[552750], label='552750', marker='o', markersize=5, linewidth=2, color="skyblue")
plt.plot(df['Cycle Number'], df[552800], label='552800', marker='o', markersize=5, linewidth=2, color="cornflowerblue")
plt.plot(df['Cycle Number'], df[552850], label='552850', marker='o', markersize=5, linewidth=2, color="darkblue")
plt.plot(df['Cycle Number'], df[822750], label='822750', marker='o', markersize=5, linewidth=2, color="hotpink")
plt.plot(df['Cycle Number'], df[822800], label='822800', marker='o', markersize=5, linewidth=2, color="mediumvioletred")
plt.plot(df['Cycle Number'], df[822850], label='822850', marker='o', markersize=5, linewidth=2, color="indigo")

plt.xticks(fontsize=12)  # Adjust the fontsize of xticks
plt.yticks(fontsize=12)

plt.xlabel('Cycle Number', fontsize=14)
plt.ylabel('Capacity/ mAh/g', fontsize=14)
plt.legend(fontsize=14, bbox_to_anchor=(1.22,0.77))  # Show legend

plt.grid(True)  # Add gridlines if needed
plt.tight_layout()


plt.text(-0.5, 92,'  C/5', fontsize=14, fontweight='bold')
plt.text(5, 83,'  C/2', fontsize=14, fontweight='bold')
plt.text(11, 76,'  C', fontsize=14, fontweight='bold')
plt.text(15.5, 67,'  2C', fontsize=14, fontweight='bold')
plt.text(20, 57,'  5C', fontsize=14, fontweight='bold')

output_file = "/Users/harryfyjis-walker/Desktop/Part II Stuff/figures/PROPER282552822RATE.png"
plt.savefig(output_file, format='png')



plt.show()
