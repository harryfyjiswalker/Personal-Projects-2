# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches

plt.rcParams['font.family'] = 'serif'

# Define a function to plot the data from a single file
def plot_single_file(ax, filename, offset):
    data = np.loadtxt(filename)
    x = data[:, 0]
    y_obs = data[:, 1]
    y_calc = data[:, 2]
    y_obs_calc = data[:, 3]

    ax.scatter(x, y_obs, s=5, color='black', label='Observed')
    ax.plot(x, y_calc, linewidth=1.5, color='red', label='Calculated')
    ax.plot(x, y_obs_calc - offset, linewidth=2, color='gray')
    ax.set_xlim(7, 35)
    ax.set_ylim(-200000, 1600000)
    #ax.set_xlabel(r'2$\theta$ / °', fontsize=16)
    ax.set_ylabel('Intensity', fontsize=16)
    ax.legend(fontsize=16)
    
    ax.set_yticks(np.arange(0, ax.get_ylim()[1], 200000))
    #ax.set_yscale('log')
            
# List of filenames
file_names = [
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/462750060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/822750060524SECONDATTEMPT.txt',
    # Add more filenames here
]

# Create subplots
fig, axs = plt.subplots(len(file_names), 1, figsize=(16, 8), sharex=True)
plt.subplots_adjust(hspace=0)

# Loop over each file
for i, filename in enumerate(file_names):
    plot_single_file(axs[i], filename, i * 50000)  # Adjust offset for each plot

#plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'serif'

# Define a function to plot the data from a single file
def plot_single_file(ax, filename, rwp_value, composition_value, offset):
    data = np.loadtxt(filename)
    x = data[:, 0]
    y_obs = data[:, 1]
    y_calc = data[:, 2]
    y_obs_calc = data[:, 3]
    offset = 10000

    ax.scatter(x, y_obs, s=5, color='black')
    ax.plot(x, y_calc, linewidth=1.5, color='red')
    ax.plot(x, y_obs_calc - offset, linewidth=2, color='gray')
    ax.set_xlim(8.3, 9.1)
    ax.set_ylim(-80000, 2000000)
    ax.set_xlabel(r'2$\theta$ / °', fontsize=16)

    # Set y-ticks greater than or equal to 0
    ax.set_yticks([])

    # Add Rwp label in top right corner with the provided value
    ax.text(0.01, 0.97, f'{composition_value}, R$_{{wp}}$= {rwp_value}', transform=ax.transAxes, ha='left', va='top', fontsize=11, color = 'red')

# List of filenames, corresponding Rwp values, and composition values
file_names = [
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/0102750060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/192750060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/282750060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/282800060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/282850060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/372750060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/462750060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/552750060524 (1).txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/552800060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/552850060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/642750060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/732750060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/822750060524SECONDATTEMPT.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/822800060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/822850060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/912750060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/1002750060524.txt',
    # Add more filenames here
]
composition_values = [102750, 192750, 282750, 282800, 282850, 372750, 462750, 552750, 552800, 552850, 642750, 732750, 822750, 822800, 822850, 912750, 1002750]  # Composition values for each plot

# Create subplots
fig, axs = plt.subplots(len(file_names), 1, figsize=(10, 10), sharex=True)

# Loop over each file
for ax, filename, rwp_value, composition_value in zip(axs, file_names, rwp_values, composition_values):
    plot_single_file(ax, filename, rwp_value, composition_value, offset)
    ax.grid(True, axis='x', linestyle='--', linewidth=0.5) 
    
fig.text(0.08, 0.5, 'Intensity', va='center', rotation='vertical', fontsize=16)

plt.subplots_adjust(hspace=0)  # No space between plots
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 56
#      54 # Loop over each file
#      55 for ax, filename, rwp_value, composition_value in zip(axs, file_names, rwp_values, composition_values):
# ---> 56     plot_single_file(ax, filename, rwp_value, composition_value, offset)
#      57     ax.grid(True, axis='x', linestyle='--', linewidth=0.5)
#      59 fig.text(0.08, 0.5, 'Intensity', va='center', rotation='vertical', fontsize=16)
#
# NameError: name 'offset' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = 'serif'

# Define a function to plot the data from a single file
def plot_single_file(ax, filename, composition_value):
    data = np.loadtxt(filename)
    x = data[:, 0]
    y_obs = data[:, 1]
    y_calc = data[:, 2]
    y_obs_calc = data[:, 3]
    offset = 10000

    ax.scatter(x, y_obs, s=1, color='black')
    ax.plot(x, y_calc, linewidth=1, color='red')
    ax.plot(x, y_obs_calc - offset, linewidth=0.5, color='gray')
    ax.set_xlim(5, 40)
    ax.set_ylim(-80000, 800000)
    ax.set_xlabel(r'2$\theta$ / °', fontsize=25)

    # Set y-ticks to be empty (remove y-ticks)
    ax.set_yticks([])

    # Add composition label in the top left corner
    ax.text(0.83, 0.97, f'{composition_value}', transform=ax.transAxes, ha='left', va='top', fontsize=17, color='red')

# List of filenames and corresponding composition values
file_names = [
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/0102750060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/192750060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/282750060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/282800060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/282850060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/372750060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/462750060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/552750060524 (1).txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/552800060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/552850060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/642750060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/732750060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/822750060524SECONDATTEMPT.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/822800060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/822850060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/912750060524.txt',
    '/Users/harryfyjis-walker/Desktop/Part II Stuff/TOPASfilesforexport/1002750060524.txt',
]
composition_values = ['0102750, x=0/12', '192750, x=1/12', '282750, x=2/12', '282800, x=2/12', '282850, x=2/12', '372750, x=3/12', '462750, x=4/12', '552750, x=5/12', '552800, x=5/12', '552850, x=5/12', '642750, x=6/12', '732750, x=7/12', '822750, x=8/12', '822800, x=8/12', '822850, x=8/12', '912750, x=9/12', '1002750, x=10/12']  # Composition values for each plot
# Create subplots
fig, axs = plt.subplots(len(file_names), 1, figsize=(16, 2 * len(file_names)), sharex=True)

# Loop over each file
for ax, filename, composition_value in zip(axs, file_names, composition_values):
    plot_single_file(ax, filename, composition_value)
    ax.grid(True, axis='x', linestyle='--', linewidth=0.5) 
    
fig.text(0.08, 0.5, 'Intensity', va='center', rotation='vertical', fontsize=25)

plt.subplots_adjust(hspace=0)  # No space between plots
output_file = "/Users/harryfyjis-walker/Desktop/Part II Stuff/figures/TOPASappendix.pdf"
plt.savefig(output_file, format='pdf', bbox_inches='tight') 
plt.show()
